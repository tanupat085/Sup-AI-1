# %%
num = [12,123,1234,12345,17,999999999,12,1] 
nummax = num[0] 
position = 0 
for m in num: 
    if(m>nummax): 
        nummax = m
        imax = position 
    position += 1
print('ตำแหน่งที่',imax,'เลข',nummax)
